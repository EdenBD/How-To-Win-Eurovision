# %%
import pandas as pd

# %%
votes_df = pd.read_excel('./eurovision_song_contest_1975_2016.xlsx')

# %%
# also drop "edition"?
votes_df = votes_df[["Year", "(semi-) final", "Edition", "Jury or Televoting", 
                     "From country", "To country", "Points"]]
votes_df.head()
# Out:
#    Year (semi-) final Edition Jury or Televoting From country To country  \
# 0  1975             f   1975f                  J      Belgium    Belgium
# 1  1975             f   1975f                  J      Belgium    Finland
# 2  1975             f   1975f                  J      Belgium     France
# 3  1975             f   1975f                  J      Belgium    Germany
# 4  1975             f   1975f                  J      Belgium    Ireland
#
#    Points
# 0       0
# 1       0
# 2       2
# 3       0
# 4      12

# %%
len(votes_df)
votes_df.describe(include='all')
# Out:
#                 Year (semi-) final Edition Jury or Televoting From country  \
# count   38181.000000         38181   38181              38181        38181
# unique           NaN             4      62                  2           53
# top              NaN             f   2016f                  J        Spain
# freq             NaN         27875    2132              36395         1236
# mean     2003.171735           NaN     NaN                NaN          NaN
# std        11.021282           NaN     NaN                NaN          NaN
# min      1975.000000           NaN     NaN                NaN          NaN
# 25%      1996.000000           NaN     NaN                NaN          NaN
# 50%      2007.000000           NaN     NaN                NaN          NaN
# 75%      2012.000000           NaN     NaN                NaN          NaN
# max      2016.000000           NaN     NaN                NaN          NaN
#
#        To country        Points  Unnamed: 7  Unnamed: 8
# ...

# %%
votes_df.dtypes
# Out:
# Year                     int64
# (semi-) final           object
# Edition                 object
# Jury or Televoting      object
# From country          category
# To country            category
# Points                   int64
# dtype: object

# %%
# TODO:

# - convert countries to categoricals?
# votes_df["From country"] = pd.Categorical(votes_df["From country"])
# votes_df["To country"] = pd.Categorical(votes_df["To country"])

# - group by from_country / sort by points to to_countries


# - exclude entries where from_country == to_country? (check that points are 0, but anyway)
# votes_df = votes_df[votes_df["From country"] != votes_df["To country"]]

# - split "jury or televoting" to 2 indicator variables


# - (technical) can just filter out 0 points to have less data (that's the default)
# votes_df = votes_df[votes_df["Points"] != 0]

# Questions:
# - What to do w/ changes in voting rules (2016)?
#

# %%
votes_df.head()
# Out:
#     Year (semi-) final Edition Jury or Televoting From country  To country  \
# 1   1975             f   1975f                  J      Belgium     Finland
# 3   1975             f   1975f                  J      Belgium     Germany
# 7   1975             f   1975f                  J      Belgium  Luxembourg
# 9   1975             f   1975f                  J      Belgium      Monaco
# 10  1975             f   1975f                  J      Belgium      Norway
#
#     Points
# 1        0
# 3        0
# 7        0
# 9        0
# 10       0
